# %% [markdown]
# ### Exportando o DataSet Credit Risk

# %%
import pandas as pd

pd.read_csv("Data_Risk/credit_risk_dataset.csv")
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 1              21           9600                   OWN                5.0
# 2              25           9600              MORTGAGE                1.0
# 3              23          65500                  RENT                4.0
# 4              24          54400                  RENT                8.0
# ...           ...            ...                   ...                ...
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
type (pd.read_csv("Data_Risk/credit_risk_dataset.csv"))
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Criando uma variável para DataFrame

# %%
DataSet_risk = pd.read_csv("Data_Risk/credit_risk_dataset.csv")

# %%
DataSet_risk
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 1              21           9600                   OWN                5.0
# 2              25           9600              MORTGAGE                1.0
# 3              23          65500                  RENT                4.0
# 4              24          54400                  RENT                8.0
# ...           ...            ...                   ...                ...
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %% [markdown]
# ### Renomeando Colunas

# %%
DataSet_risk = DataSet_risk.rename(columns={'person_age': 'Idade da pessoa'}).rename(columns={'person_income': 'Renda Pessoal'})

# %%
DataSet_risk
# Out:
#        Idade da pessoa  Renda Pessoal person_home_ownership  \
# 0                   22          59000                  RENT
# 1                   21           9600                   OWN
# 2                   25           9600              MORTGAGE
# 3                   23          65500                  RENT
# 4                   24          54400                  RENT
# ...                ...            ...                   ...
# 32576               57          53000              MORTGAGE
# 32577               54         120000              MORTGAGE
# 32578               65          76000                  RENT
# 32579               56         150000              MORTGAGE
# 32580               66          42000                  RENT
#
#        person_emp_length      loan_intent loan_grade  loan_amnt  \
# 0                  123.0         PERSONAL          D      35000
# 1                    5.0        EDUCATION          B       1000
# ...

# %%
DataSet_risk.columns
# Out:
# Index(['Idade da pessoa', 'Renda Pessoal', 'person_home_ownership',
#        'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'loan_int_rate', 'loan_status', 'loan_percent_income',
#        'cb_person_default_on_file', 'cb_person_cred_hist_length'],
#       dtype='object')

# %%
DataSet_risk = DataSet_risk.rename(columns={
    'idade da pessoa': 'Idade',
    'Renda Pessoal': 'Renda',
    'person_home_ownership': 'Propriedade',
    'person_emp_length': 'Tempo de Emprego',
    'loan_intent': 'Intenção do Empréstimo',
    'loan_grade': 'Nota do Empréstimo',
    'loan_amnt': 'Valor do Empréstimo',
    'loan_int_rate': 'Taxa de Juros',
    'loan_status': 'Status do Empréstimo',
    'loan_percent_income': 'Percentual da Renda',
    'cb_person_default_on_file': 'Histórico de Inadimplência',
    'cb_person_cred_hist_length': 'Tempo de Histórico de Crédito'})

# %% [markdown]
# ### Verificando as informações DataFrame

# %%
DataSet_risk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Idade da pessoa                32581 non-null  int64
#  1   Renda                          32581 non-null  int64
#  2   Propriedade                    32581 non-null  object
#  3   Tempo de Emprego               31686 non-null  float64
#  4   Intenção do Empréstimo         32581 non-null  object
#  5   Nota do Empréstimo             32581 non-null  object
#  6   Valor do Empréstimo            32581 non-null  int64
#  7   Taxa de Juros                  29465 non-null  float64
#  8   Status do Empréstimo           32581 non-null  int64
#  9   Percentual da Renda            32581 non-null  float64
#  10  Histórico de Inadimplência     32581 non-null  object
#  11  Tempo de Histórico de Crédito  32581 non-null  int64
# ...

# %% [markdown]
# ### Verificando se existe menor de idade

# %%
DataSet_risk['Idade da pessoa'].values <18
# Out:
# array([False, False, False, ..., False, False, False])

# %% [markdown]
# ### Chegando a conclusão que não existe

# %%
DataSet_risk. describe()
# Out:
#        Idade da pessoa         Renda  Tempo de Emprego  Valor do Empréstimo  \
# count     32581.000000  3.258100e+04      31686.000000         32581.000000
# mean         27.734600  6.607485e+04          4.789686          9589.371106
# std           6.348078  6.198312e+04          4.142630          6322.086646
# min          20.000000  4.000000e+03          0.000000           500.000000
# 25%          23.000000  3.850000e+04          2.000000          5000.000000
# 50%          26.000000  5.500000e+04          4.000000          8000.000000
# 75%          30.000000  7.920000e+04          7.000000         12200.000000
# max         144.000000  6.000000e+06        123.000000         35000.000000
#
#        Taxa de Juros  Status do Empréstimo  Percentual da Renda  \
# count   29465.000000          32581.000000         32581.000000
# mean       11.011695              0.218164             0.170203
# std         3.240459              0.413006             0.106782
# ...

# %%
import numpy as np

# %%
DataSet_risk[['Idade da pessoa']] .describe()
# Out:
#        Idade da pessoa
# count     32581.000000
# mean         27.734600
# std           6.348078
# min          20.000000
# 25%          23.000000
# 50%          26.000000
# 75%          30.000000
# max         144.000000

# %%
DataSet_risk['Idade da pessoa'].quantile(0.25)
# Out:
# np.float64(23.0)

# %%
quartil = DataSet_risk['Idade da pessoa'].quantile(0.25) 
print(f"{quartil :.2f}%")
# Out:
# 23.00%

# %% [markdown]
# ### Mostrando somente a porcentagem da coluna idade

# %%
quartil = DataSet_risk['Idade da pessoa'].count() 
print(f"{quartil :.2f}%")
# Out:
# 32581.00%

# %% [markdown]
# ### Mostrando somente a media da coluna idade

# %%
media = DataSet_risk['Idade da pessoa'].mean()
print(f"{media:.2f}%")
# Out:
# 27.73%
